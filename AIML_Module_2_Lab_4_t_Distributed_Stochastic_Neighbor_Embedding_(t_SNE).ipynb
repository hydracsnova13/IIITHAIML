# %% [markdown]
# <a href="https://colab.research.google.com/github/hydracsnova13/IIITHAIML/blob/iiithCourse/AIML_Module_2_Lab_4_t_Distributed_Stochastic_Neighbor_Embedding_(t_SNE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 2: Appreciating, Interpreting and Visualizing Data
# ## Lab 4: t-Distributed Stochastic Neighbor Embedding (t-SNE)
#
# ---

# %% [markdown]
# This lab will be based upon t-SNE which is a dimensionality reduction algorithm used to visualize high dimensional datasets.
#
# t-SNE stands for t-Distributed Stochastic Neighbor Embedding. It is an unsupervised, non-linear technique primarily used for data exploration and visualizing high-dimensional data. It was developed by Laurens van der Maatens and Geoffrey Hinton in 2008 (Link to the paper: https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# t-SNE has a tuneable parameter, **perplexity** which balances attention between the local and global aspects of your data. It is a guess about the number of close neighbors each point has. The perplexity value has a complex effect on the resulting pictures. The original paper says, “The performance of t-SNE is fairly robust to changes in the perplexity, and typical values are between 5 and 50.” But the story is more nuanced than that. Getting the most from t-SNE may mean analyzing multiple plots with different perplexities.
#
# Also the t-SNE algorithm doesn’t always produce similar output on successive runs as there are additional hyperparameters related to the optimization process.

# %% [markdown]
# ### HOW DOES T-SNE WORK??
#
# The t-SNE algorithm calculates a similarity measure between pairs of instances in the high dimensional space and in the low dimensional space. It then tries to optimize these two similarity measures using a cost function. Let’s break that down into 3 basic steps.
#
# 1. Measure similarities between points in the high dimensional space. Think of a bunch of data points scattered on a 2D space. For each data point (xi) we’ll center a Gaussian distribution over that point. Then we measure the density of all points (xj) under that Gaussian distribution. Then renormalize for all points. This gives us a set of probabilities (Pij) for all points. Those probabilities are proportional to the similarities. All that means is, if data points x1 and x2 have equal values under this gaussian circle then their proportions and similarities are equal and hence you have local similarities in the structure of this high-dimensional space. The Gaussian distribution or circle can be manipulated using what’s called perplexity, which influences the variance of the distribution (circle size) and essentially the number of nearest neighbors.
#
# 2. This step is similar to step 1, but instead of using a Gaussian distribution we use a Student t-distribution with one degree of freedom, which is also known as the Cauchy distribution (See fig below). This gives us a second set of probabilities (Qij) in the low dimensional space. As you can see the Student t-distribution has heavier tails than the normal distribution. The heavy tails allow for better modeling of far apart distances.
#
# 3. The last step is that we want these set of probabilities from the low-dimensional space (Qij) to reflect those of the high dimensional space (Pij) as best as possible. We want the two map structures to be similar. We measure the difference between the probability distributions of the two-dimensional spaces using Kullback-Liebler divergence (KL). Finally, we use gradient descent to minimize our KL cost function.

# %% [markdown]
# ![students_t.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Scikit-learn has an implementation of t-SNE available which provides a wide variety of tuning parameters for t-SNE, and the most notable ones are:
#
# 1. n_components (default: 2): Dimension of the embedded space.
# 2. perplexity (default: 30): The perplexity is related to the number of nearest neighbors that are used in other manifold learning algorithms. Consider selecting a value between 5 and 50.
# 3. n_iter (default: 1000): Maximum number of iterations for the optimization. Should be at least 250.
# 4. method (default: ‘barnes_hut’): Barnes-Hut approximation runs in O(NlogN) time. method=’exact’ will run on the slower, but exact, algorithm in O(N^2) time.

# %%
# numpy.
import numpy as np
from numpy import linalg
from numpy.linalg import norm
from scipy.spatial.distance import squareform, pdist

# sklearn.
import sklearn
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
from sklearn.preprocessing import scale

# Random state.
RS = 20150101

# matplotlib.
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib
# %matplotlib inline

# seaborn.
import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale=1.5,
                rc={"lines.linewidth": 2.5})

# %% [markdown]
# 1797 images each of size 8 x 8 loaded using load_digits()

# %%
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %% [markdown]
# Printing some images from the dataset
#
# ---

# %%
nrows, ncols = 2, 5
plt.figure(figsize=(6,3))
plt.gray()
for i in range(ncols * nrows):
    ax = plt.subplot(nrows, ncols, i + 1)
    ax.matshow(digits.images[i,...])
    plt.xticks([]); plt.yticks([])
    plt.title(digits.target[i])

# %%
# We first reorder the data points according to the handwritten numbers.
X = np.vstack([digits.data[digits.target==i]
               for i in range(10)])
y = np.hstack([digits.target[digits.target==i]
               for i in range(10)])

# %% [markdown]
# ## Now using TSNE to fit the dataset with the default values.
#
#
# 1. n_components : 2
# 2. perplexity : 30
# 3. n_iter : 1000
# 4. method : ‘barnes_hut’
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS).fit_transform(X)

# %% [markdown]
# #### Visualizing the data in the projected space
#
# ---

# %%
def scatter(x, colors):
    # We choose a color palette with seaborn.
    palette = np.array(sns.color_palette("hls", 10))

    # We create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,
                    c=palette[colors.astype(int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # We add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)
    plt.show()

    return f, ax, sc

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075ee75cc0>)

# %% [markdown]
# # Tweaking some of the hyperparameters to better understand their role
#
# ---
#
# ### Changing the PERPLEXITY values

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# With perplexity values in the range (5 - 50) suggested by van der Maaten & Hinton, the diagrams do show these clusters, although with very different shapes. Outside that range, things get a little weird. With perplexity 2, local variations dominate. The image for perplexity 100, with merged clusters, illustrates a pitfall: for the algorithm to operate properly, the perplexity really should be smaller than the number of points. Implementations can give unexpected behavior otherwise.

# %% [markdown]
# ---
#
#
# 1. n_components : 2
# 2. perplexity : **5**
# 3. n_iter : 1000
# 4. method : ‘barnes_hut’
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS, perplexity=5).fit_transform(X)

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075ee748b0>)

# %% [markdown]
# We can see that there are local clusters within the same number group as well. This is happening as the perplexity being at 5, allows the local neighbourhood to dominate. Let us now see what happens if we increase the perplexity to 100, thereby increasing global impact.

# %% [markdown]
# ---
#
#
# 1. n_components : 2
# 2. perplexity : **100**
# 3. n_iter : 1000
# 4. method : ‘barnes_hut’
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS, perplexity=100).fit_transform(X)

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075ef4eec0>)

# %% [markdown]
# The general structure of the plot remained similar to the one with perplexity = 30 (default), but on careful observation you can observe many data points not being part of the group they are supposed to be in. This is because of the large number of points considered for the neighbourhood (as perplexity value = 100 is higher), thereby allowing 2 data points from different groups to end up closer.
#
#
#
# ---
#
# ### Changing the NUMBER OF ITERATIONS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The images above show five different runs at perplexity 30. The first four were stopped before stability. After 10, 20, 60, and 120 steps you can see layouts with seeming 1-dimensional and even pointlike images of the clusters. If you see a t-SNE plot with strange “pinched” shapes, chances are the process was stopped too early. Unfortunately, there’s no fixed number of steps that yields a stable result. Different data sets can require different numbers of iterations to converge.
#
# The most important thing is to iterate until reaching a stable configuration.

# %% [markdown]
# ---
#
#
# 1. n_components : 2
# 2. perplexity : 30
# 3. n_iter : **250**
# 4. method : ‘barnes_hut’
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS, n_iter=250).fit_transform(X)

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075d5ef6d0>)

# %% [markdown]
# As can be seen from the figure above, stopping the optimization earlier (in 250 iterations) resulted in a suboptimal clustering of the groups.
#
# Let us now see how the results are affected if t-SNE is run for larger number of iterations
#
#
# ---
#
#
# 1. n_components : 2
# 2. perplexity : 30
# 3. n_iter : **5000**
# 4. method : ‘barnes_hut’
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS, n_iter=5000).fit_transform(X)

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075d46a620>)

# %% [markdown]
# Running for larger number of iterations more or less resulted in the same plot as the optimization had nearly converged till the default 1000 iterations. However the density of the clusters has increased.
#
# ---
#
# ### Changing the method to EXACT
#
# The barnes-hut method takes O(NlogN) time, whereas the exact method takes O(N^2) time. Notice the increase in the execution time while running the cell below.
#
#
# ---
#
# 1. n_components : 2
# 2. perplexity : 30
# 3. n_iter : 1000
# 4. method : **‘exact’**
#
#
# ---

# %%
digits_proj = TSNE(init="pca", random_state=RS, method='exact').fit_transform(X)

scatter(digits_proj, y)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.collections.PathCollection at 0x7a075d4e30a0>)

# %% [markdown]
# ## EXERCISE
#
# ---
#
#
#
# Try out different perplexity and iteration values to better appreciate the concepts taught.
#
# You can modify the code in the cell below to check the resultant plots.

# %%
###############################################################
###### MODIFY THE VALUES FOR THE HYPERPARAMETERS BELOW ########

perplexity_value = {20,30,40,50,60,70,80,90}
number_iterations = 1000
method = "barnes_hut"

###############################################################

for p in perplexity_value:
  digits_proj = TSNE(init="pca", random_state=RS, n_iter=number_iterations, perplexity=p, method=method).fit_transform(X)
  scatter(digits_proj, y)

# %% [markdown]
# ---
#
# ## QUESTION:
#
# Now that you understand t-SNE a bit better, can you point out some differences between PCA and t-SNE. What are the advantages/disadvantages of one over the other?
#
#
# ##### Pointers:
#
# 1. Which of the two algorithms is linear and which one is non-linear?
# 2. How does the non-linearity in one of these two algorithms help in capturing certain data sets?
# 3. PCA is known to keep points which were further apart in the higher dimension, far apart in the lower dimension as well. Does t-SNE do the same? Or does it try to preserve local neighbourhood?
# 4. Can you comment on which one of the two is computationally more expensive?

# %% [markdown]
# ---

# %% [markdown]
#  answer 1:
#  PCA (Principal Component Analysis) is a linear dimensionality reduction algorithm. It operates by finding linear combinations of the original features to project the data into a lower-dimensional space, preserving linear relationships and variances in the data.
#
# t-SNE (t-Distributed Stochastic Neighbor Embedding) is a non-linear dimensionality reduction algorithm. It aims to preserve the local relationships and similarities between data points, making it suitable for capturing non-linear structures in the data.

# %% [markdown]
# ---

# %% [markdown]
# answer 2:
# The non-linearity in t-SNE (t-Distributed Stochastic Neighbor Embedding) helps capture certain data sets by allowing the algorithm to model and represent complex, non-linear relationships and structures in the data. Here's how this non-linearity is beneficial for capturing such data sets:
#
# Capturing Non-Linear Clusters: Many real-world data sets exhibit non-linear patterns and structures. For example, clusters of data points in high-dimensional space may form intricate shapes or have non-linear boundaries. t-SNE is designed to preserve the local relationships and similarities between data points, making it effective at capturing and visualizing these non-linear clusters. It can reveal subtle groupings that might be hidden when using linear methods like PCA.
#
# Handling Manifolds: Data often resides on or near low-dimensional manifolds embedded within higher-dimensional spaces. These manifolds can have complex, non-linear shapes. t-SNE's non-linearity helps it map data points onto lower-dimensional spaces while preserving the intricate structures of these manifolds. This is particularly valuable in tasks like manifold learning and dimensionality reduction when the underlying data distribution is non-linear.
#
# Separating Overlapping Clusters: In some cases, clusters or groups of data points may overlap or intersect in high-dimensional space, making it challenging to distinguish them using linear techniques. t-SNE's non-linear approach can separate overlapping clusters more effectively by modeling the local relationships and similarities between points, allowing it to push similar points closer together and dissimilar points farther apart.
#
# Capturing Fine-Grained Structures: When there are fine-grained structures or local patterns in the data, t-SNE excels at preserving them. This is useful in tasks such as visualizing data, exploring complex data distributions, or identifying intricate relationships that linear methods might miss.
#
# However, it's essential to note that while t-SNE is powerful for capturing non-linear structures, it is also computationally more intensive and may require careful tuning of hyperparameters to obtain optimal results. The choice between PCA and t-SNE depends on the specific goals of the analysis and the nature of the data, with t-SNE being a valuable tool when non-linearity and local relationships are of primary importance.

# %% [markdown]
# ---

# %% [markdown]
# answer 3:
# PCA and t-SNE have different approaches to preserving the relationships between data points in the lower-dimensional space:
#
# PCA:
#
# PCA aims to preserve the global structure of the data. It ensures that points that were further apart in the higher-dimensional space remain relatively far apart in the lower-dimensional space. This means it tries to maintain the relative distances and variances between data points. However, PCA does not specifically focus on preserving local neighborhood relationships.
# t-SNE:
#
# t-SNE, in contrast, is designed to preserve local neighborhood relationships. It focuses on keeping similar data points close to each other in the lower-dimensional space and attempts to minimize the distances between them. It does this by using a probability distribution to represent the similarity between data points and then optimizing the embedding to minimize the divergence between the high-dimensional and low-dimensional distributions. This emphasis on preserving local neighborhoods makes t-SNE particularly useful for visualizing clusters and fine-grained structures in the data.
# So, t-SNE does not prioritize keeping points that were further apart in the higher dimension far apart in the lower dimension, as PCA does. Instead, it tries to maintain the relative similarities and neighborhoods of data points, which is especially valuable when dealing with non-linear data and when the local relationships between data points are of particular interest.

# %% [markdown]
# ---

# %% [markdown]
# answer 4:
# t-SNE (t-Distributed Stochastic Neighbor Embedding) is generally computationally more expensive compared to PCA (Principal Component Analysis). The computational complexity of each method differs due to their underlying algorithms:
#
# PCA:
#
# PCA is computationally more efficient. The primary computational steps in PCA involve eigenvalue decomposition or singular value decomposition (SVD) of the data's covariance matrix. These operations can be computed efficiently using numerical algorithms like the power iteration or Lanczos method. The time complexity of PCA typically scales linearly with the number of features (dimensions) in the data. Therefore, PCA is well-suited for handling high-dimensional data efficiently.
# t-SNE:
#
# t-SNE is computationally more expensive, especially for large datasets or high-dimensional data. The primary operations in t-SNE involve computing pairwise similarities between data points and performing non-linear optimization to embed the data into a lower-dimensional space. The optimization often requires iterative techniques like gradient descent, and the algorithm's time complexity can be much higher than that of PCA, particularly when dealing with high-dimensional spaces. The optimization process, including the computation of conditional probabilities and gradient updates, can be time-consuming.
# As a result, when computational efficiency is a significant concern, PCA is a more practical choice. t-SNE may be reserved for scenarios where capturing non-linear relationships and preserving local neighborhood structures in the data are of paramount importance, and the computational cost is acceptable. However, users should be aware that t-SNE's runtime can be considerably longer than PCA, especially for large and complex datasets.

# %% [markdown]
# ---
#  ## Some interesting references:
#
#  1. https://blog.paperspace.com/dimension-reduction-with-t-sne/
#  2. https://towardsdatascience.com/an-introduction-to-t-sne-with-python-example-5a3a293108d1
#  3. https://distill.pub/2016/misread-tsne/
#
#
#
# ---
